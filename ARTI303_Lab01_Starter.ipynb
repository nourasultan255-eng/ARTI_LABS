# %% [markdown]
# # Lab 1 — Environment & Python Basics
# **ARTI 303 — Programming for AI**
#
# **Name:** _[Noura Alsultan]_
# **Student ID:** _[2250005723]_
# **Section:** _[AI2]_
#
# This notebook is Part B of Lab 1. Part A (creating the repository structure) happens outside this notebook. Once this notebook is complete, it belongs at `notebooks/lab01.ipynb` inside your semester repository.
#
# Work through the cells top to bottom. Each task has a `# TODO` comment
# telling you what to build, followed by a self-check cell — run it after
# your answer; if it prints an `AssertionError`, your answer isn't right yet.

# %% [markdown]
# ## Part B:
#
# You are building a single **student record** using plain variables — one
# name per field. (Lists and dictionaries are Lab 2. For now, one variable
# per fact about one student.)

# %% [markdown]
# ### Task 1 — Create the record
# Create four variables describing one student:
# - `name` — a string
# - `age` — an integer
# - `gpa` — a float, out of 4.0
# - `is_enrolled` — a boolean

# %%
# TODO: replace the None values below
name = "NOURA ALSULTAN"         # e.g. "Sara Al-Otaibi"
age = 20           # e.g. 20
gpa = 3.5       # e.g. 3.6
is_enrolled = True    # True or False

# %%
# Self-check — do not edit this cell
assert isinstance(name, str) and len(name) > 0, "name should be a non-empty string"
assert isinstance(age, int) and not isinstance(age, bool), "age should be an int"
assert isinstance(gpa, float), "gpa should be a float, e.g. 3.6 not 3"
assert isinstance(is_enrolled, bool), "is_enrolled should be True or False"
print("Task 1 looks correct.")
# Out:
# Task 1 looks correct.

# %% [markdown]
# ### Task 2 — Dean's list check
# Using a comparison operator, work out whether this student qualifies for
# the Dean's list (`gpa >= 3.5`). Store the result in a new variable
# `dean_list` — don't just print it, **store it**.

# %%
# TODO: compute dean_list using a comparison operator on gpa
dean_list = gpa>= 3.5

# %%
# Self-check
assert isinstance(dean_list, bool), "dean_list should be a boolean (True/False)"
assert dean_list == (gpa >= 3.5), "dean_list doesn't match the gpa you set"
print("Task 2 looks correct.")
# Out:
# Task 2 looks correct.

# %% [markdown]
# ### Task 3 — Report line
# Build **one** f-string that reads naturally, e.g.:
#
# `"Omar Al-Zahrani (age 22, GPA 4.60) is enrolled and made the Dean's list."`
#
# It must use every variable from Task 1 and 2. Store it in `report`, then
# print it.

# %%
# TODO: build the f-string
report =  f"{name} is {age} years old, has a GPA of {gpa:.2f}, enrolled: {is_enrolled}, Dean's list: {dean_list}"

print(report)

print(report)
# Out:
# NOURA ALSULTAN is 20 years old, has a GPA of 3.50, enrolled: True, Dean's list: True
# NOURA ALSULTAN is 20 years old, has a GPA of 3.50, enrolled: True, Dean's list: True

# %%
# Self-check
assert isinstance(report, str) and name in report and str(age) in report, \
    "report should be an f-string that includes the name and age"
print("Task 3 looks correct.")
# Out:
# Task 3 looks correct.

# %% [markdown]
# **Done when:** all three self-check cells above print "looks correct"
# with no `AssertionError`.

# %% [markdown]
# ### Task 4 — Casting and a real error
# Data rarely arrives in the type you want. Below, `raw_gpa` is a *string*
# that looks like a number.
#
# 1. Convert it to a float and store it as `raw_gpa_value`.
# 2. Then, **on purpose**, try to convert `bad_value` to a float the same
#    way, inside a `try`/`except` block, and print a friendly message
#    instead of letting the program crash.
#
# This is your first look at reading a Python error message.

# %%
raw_gpa = "3.87"
bad_value = "N/A"

# TODO: convert raw_gpa to a float
raw_gpa_value = float (raw_gpa)

# TODO: wrap the conversion of bad_value in try/except ValueError,
# and print a message such as: "Could not convert 'N/A' to a number."
try:
    value = float(bad_value)
except ValueError:
    print(f"Could not convert '{bad_value}' to a number.")
# Out:
# Could not convert 'N/A' to a number.

# %%
# Self-check
assert isinstance(raw_gpa_value, float) and abs(raw_gpa_value - 3.87) < 1e-9
print("Task 4 looks correct.")
# Out:
# Task 4 looks correct.

# %% [markdown]
# ### Task 5 — A second and third record
# Copy the pattern from Task 1–3 to create **two more** student records —
# use new variable names for each (e.g. `name2`, `age2`, ... or pick your
# own convention). Print all three report lines, one per line.
#
# You will notice this gets repetitive with three students. That repetition
# is deliberate — Week 2 introduces lists and loops specifically to remove
# it. Don't reach for a list yet.

# %%
# TODO: second student record + report line
name2 = "Sara"
age2 = 21
gpa2 = 3.4 
is_enrolled2 = True

dean_list2 = gpa2 >= 3.5


report2 = f"{name2} (age {age2}, GPA {gpa2:.2f}) - enrolled: {is_enrolled2}, Dean's list: {dean_list2}"

# TODO: third student record + report line

name3 = "Layan" 
age3 = 19 
gpa3 = 3.9 
is_enrolled3 = True

dean_list3 = gpa3 >= 3.5


report3 = f"{name3} (age {age3}, GPA {gpa3:.2f}) - enrolled: {is_enrolled3}, Dean's list: {dean_list3}"
print(report) 
print(report2) 
print(report3)
# Out:
# NOURA ALSULTAN is 20 years old, has a GPA of 3.50, enrolled: True, Dean's list: True
# Sara (age 21, GPA 3.40) - enrolled: True, Dean's list: False
# Layan (age 19, GPA 3.90) - enrolled: True, Dean's list: True

# %% [markdown]
# ## Challenge:
# No single correct answer is expected here; this will not be checked by an
# assert cell.

# %% [markdown]
# ### Task 6 — A first look at a formula you'll meet again
# Using only variables and arithmetic operators (no imports), compute
# `y = m * x + b` for hard-coded values of `m`, `x`, and `b` of your
# choosing, and print the result with a one-line explanation of what it
# represents.
#
# Keep this cell — this exact formula reappears in Week 5 (NumPy / linear
# algebra), and again as the starting point for a single artificial
# neuron later in the semester.

# %%
# TODO: pick your own m, x, b and compute y
m = 2
x = 5
b = 3

y = m * x + b

print(f"Using y = m*x + b, the result is y = {y}")
# Out:
# Using y = m*x + b, the result is y = 13

# %% [markdown]
# ## Part C — AI checkpoint
#
# **Pattern: Generate and verify.**
#
# 1. Open an AI coding assistant (ChatGPT, Copilot, Claude — whichever you
#    have access to) and give it this exact prompt, unmodified:
#
#    > *"Write a Python program that stores a person's name and age as
#    > variables and prints a sentence combining them."*
#
# 2. Paste **exactly** what it gave you into the code cell below and run it.
# 3. Answer the three questions in the markdown cell after that — in your
#    own words, a sentence or two each. This is what gets checked in your
#    AI usage log, not the generated code itself.

# %%
# Paste the AI assistant's output here, unmodified, and run it.
name = "Sara"
age = 20

print(f"{name} is {age} years old.")
# Out:
# Sara is 20 years old.

# %% [markdown]
# **Q1. Verification —** did it actually do what was asked? How do you
# know — what did you check?
#
# Yes, it did what was asked. I checked that it created variables for the person’s name and age and printed both values together in one sentence.
#
# **Q2. Technique —** how did it build the sentence (f-string? `.format()`?
# string concatenation with `+`?) — and is that what Section 3 of the lab sheet recommends?
#
# It used an f-string to combine the variables with the text. Yes, this matches the technique recommended in the lab.
#
# **Q3. One change —** name one thing you would change about the generated code, and why.
#
# I would change the example name and age to my own values because it would make the program more personalized.

# %% [markdown]
# ---
# ### Before you commit
#
# - [ ] All three Core self-check cells print "looks correct"
# - [ ] Stretch and Challenge attempted (they don't need to be perfect)
# - [ ] Part C filled in with your own AI output and your own answers
# - [ ] Restart the kernel and Run All — the whole notebook should run
#       top to bottom with no errors before you commit it

# %% [markdown]
# **End of Notebook**
